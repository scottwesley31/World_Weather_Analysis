# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude comibinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | antanifotsy
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hambantota
# Processing Record 8 of Set 1 | los llanos de aridane
# Processing Record 9 of Set 1 | jan kempdorp
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | labuhan
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | kalmunai
# Processing Record 15 of Set 1 | bitkine
# Processing Record 16 of Set 1 | saint-augustin
# Processing Record 17 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | diego de almagro
# Processing Record 21 of Set 1 | grand gaube
# Processing Record 22 of Set 1 | pochutla
# Processing Record 23 of Set 1 | cap malheureux
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | jeremoabo
# Processing Record 34 of Set 1 | ouegoa
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | tekax
# City not found. Skipping...
# Processing Record 37 of Set 1 | nara
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | calama
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | kudat
# Processing Record 47 of Set 1 | lazurne
# Processing Record 48 of Set 1 | acarau
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | jackson
# Processing Record 5 of Set 2 | bilibino
# Processing Record 6 of Set 2 | vega de alatorre
# Processing Record 7 of Set 2 | erzin
# Processing Record 8 of Set 2 | ushtobe
# Processing Record 9 of Set 2 | hami
# Processing Record 10 of Set 2 | andrushivka
# Processing Record 11 of Set 2 | laramie
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | sept-iles
# Processing Record 17 of Set 2 | ciudad bolivar
# Processing Record 18 of Set 2 | necochea
# Processing Record 19 of Set 2 | buala
# Processing Record 20 of Set 2 | lodwar
# Processing Record 21 of Set 2 | samarai
# Processing Record 22 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | ludza
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | korla
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | port-gentil
# Processing Record 32 of Set 2 | nalut
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | ozernovskiy
# Processing Record 35 of Set 2 | kenora
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | norman wells
# Processing Record 41 of Set 2 | moron
# Processing Record 42 of Set 2 | talcahuano
# Processing Record 43 of Set 2 | ketchikan
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | puerto escondido
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | pula
# Processing Record 48 of Set 2 | maizuru
# Processing Record 49 of Set 2 | egvekinot
# Processing Record 50 of Set 2 | oxapampa
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | kununurra
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | acajutla
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | kapoeta
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | yerbogachen
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 14 of Set 3 | tanda
# Processing Record 15 of Set 3 | brahmapuri
# City not found. Skipping...
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | college
# Processing Record 19 of Set 3 | sur
# Processing Record 20 of Set 3 | kainantu
# Processing Record 21 of Set 3 | port macquarie
# Processing Record 22 of Set 3 | concordia
# Processing Record 23 of Set 3 | correia pinto
# Processing Record 24 of Set 3 | prince rupert
# Processing Record 25 of Set 3 | samfya
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | beringovskiy
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | valle de allende
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | gambo
# Processing Record 37 of Set 3 | pecos
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | adrar
# Processing Record 40 of Set 3 | tigil
# Processing Record 41 of Set 3 | yenagoa
# Processing Record 42 of Set 3 | omboue
# Processing Record 43 of Set 3 | machilipatnam
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | comodoro rivadavia
# Processing Record 48 of Set 3 | mokrousovo
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | ilebo
# Processing Record 1 of Set 4 | ilo
# Processing Record 2 of Set 4 | clonakilty
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | kazanskaya
# Processing Record 5 of Set 4 | brownsville
# Processing Record 6 of Set 4 | ashqelon
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | songjianghe
# Processing Record 10 of Set 4 | khandyga
# Processing Record 11 of Set 4 | lasa
# Processing Record 12 of Set 4 | sola
# Processing Record 13 of Set 4 | umbuzeiro
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | san marcos
# Processing Record 17 of Set 4 | samdari
# Processing Record 18 of Set 4 | flinders
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | beaverlodge
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | varzea da palma
# Processing Record 23 of Set 4 | les cayes
# Processing Record 24 of Set 4 | falkoping
# City not found. Skipping...
# Processing Record 25 of Set 4 | ixtapa
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | argelia
# Processing Record 28 of Set 4 | tara
# Processing Record 29 of Set 4 | chagoda
# Processing Record 30 of Set 4 | artesia
# Processing Record 31 of Set 4 | dhidhdhoo
# Processing Record 32 of Set 4 | havelock
# Processing Record 33 of Set 4 | vimperk
# Processing Record 34 of Set 4 | samur
# Processing Record 35 of Set 4 | mataura
# Processing Record 36 of Set 4 | emerald
# Processing Record 37 of Set 4 | port moresby
# Processing Record 38 of Set 4 | burnie
# Processing Record 39 of Set 4 | hearst
# Processing Record 40 of Set 4 | wanning
# Processing Record 41 of Set 4 | qasigiannguit
# Processing Record 42 of Set 4 | iskateley
# Processing Record 43 of Set 4 | huarmey
# Processing Record 44 of Set 4 | ovruch
# Processing Record 45 of Set 4 | corinth
# Processing Record 46 of Set 4 | kidal
# Processing Record 47 of Set 4 | buchanan
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | toyooka
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | solnechnyy
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | tongzi
# Processing Record 4 of Set 5 | ayame
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | dwarka
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | santiago del estero
# Processing Record 9 of Set 5 | gidam
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | majene
# Processing Record 12 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 5 | port blair
# Processing Record 14 of Set 5 | severo-yeniseyskiy
# Processing Record 15 of Set 5 | nacimiento
# Processing Record 16 of Set 5 | barcelos
# Processing Record 17 of Set 5 | aviles
# Processing Record 18 of Set 5 | hervey bay
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | high rock
# Processing Record 21 of Set 5 | ravar
# Processing Record 22 of Set 5 | sokoto
# Processing Record 23 of Set 5 | lubao
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | praia da vitoria
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | kargopol
# Processing Record 29 of Set 5 | uvat
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | hay river
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | dulce grande
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | banga
# Processing Record 39 of Set 5 | riyadh
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | sabzevar
# Processing Record 42 of Set 5 | magadan
# Processing Record 43 of Set 5 | illapel
# Processing Record 44 of Set 5 | williston
# Processing Record 45 of Set 5 | progreso
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 5 | olafsvik
# Processing Record 50 of Set 5 | rio grande
# Processing Record 1 of Set 6 | stornoway
# Processing Record 2 of Set 6 | sangar
# Processing Record 3 of Set 6 | luganville
# Processing Record 4 of Set 6 | helena
# Processing Record 5 of Set 6 | priekule
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | gornyy
# Processing Record 9 of Set 6 | kapenguria
# Processing Record 10 of Set 6 | poum
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | wuan
# Processing Record 13 of Set 6 | mahebourg
# Processing Record 14 of Set 6 | kualakapuas
# Processing Record 15 of Set 6 | tilichiki
# Processing Record 16 of Set 6 | manado
# Processing Record 17 of Set 6 | kyaukse
# Processing Record 18 of Set 6 | port lincoln
# Processing Record 19 of Set 6 | el carmen
# Processing Record 20 of Set 6 | revelstoke
# Processing Record 21 of Set 6 | abu dhabi
# Processing Record 22 of Set 6 | lumby
# Processing Record 23 of Set 6 | khatanga
# Processing Record 24 of Set 6 | mpanda
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | khair
# Processing Record 28 of Set 6 | butajira
# Processing Record 29 of Set 6 | kuytun
# Processing Record 30 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 6 | san matias
# Processing Record 32 of Set 6 | proletarskiy
# Processing Record 33 of Set 6 | huilong
# Processing Record 34 of Set 6 | saint-joseph
# Processing Record 35 of Set 6 | mayumba
# Processing Record 36 of Set 6 | salawagan
# Processing Record 37 of Set 6 | belyye berega
# Processing Record 38 of Set 6 | khor
# Processing Record 39 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 40 of Set 6 | tombouctou
# Processing Record 41 of Set 6 | talnakh
# Processing Record 42 of Set 6 | dnipryany
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | cedar mill
# Processing Record 45 of Set 6 | merrill
# Processing Record 46 of Set 6 | scarborough
# Processing Record 47 of Set 6 | mount gambier
# Processing Record 48 of Set 6 | amapa
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | mackenzie
# Processing Record 3 of Set 7 | bambous virieux
# Processing Record 4 of Set 7 | bonfim
# Processing Record 5 of Set 7 | suez
# Processing Record 6 of Set 7 | severo-kurilsk
# Processing Record 7 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | ribeira brava
# Processing Record 10 of Set 7 | katangli
# Processing Record 11 of Set 7 | turayf
# Processing Record 12 of Set 7 | ust-nera
# Processing Record 13 of Set 7 | big spring
# Processing Record 14 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 7 | svetlyy
# Processing Record 16 of Set 7 | gazojak
# Processing Record 17 of Set 7 | hobyo
# Processing Record 18 of Set 7 | pangai
# Processing Record 19 of Set 7 | ilheus
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | tabas
# Processing Record 22 of Set 7 | faanui
# Processing Record 23 of Set 7 | vernon
# Processing Record 24 of Set 7 | bedi
# Processing Record 25 of Set 7 | broome
# Processing Record 26 of Set 7 | mozarlandia
# Processing Record 27 of Set 7 | lazaro cardenas
# Processing Record 28 of Set 7 | karratha
# Processing Record 29 of Set 7 | machali
# Processing Record 30 of Set 7 | mehamn
# Processing Record 31 of Set 7 | manokwari
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | olavarria
# Processing Record 34 of Set 7 | honiara
# Processing Record 35 of Set 7 | vieques
# Processing Record 36 of Set 7 | saint-pierre
# Processing Record 37 of Set 7 | suntar
# Processing Record 38 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 7 | kuito
# Processing Record 40 of Set 7 | najran
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | grootfontein
# Processing Record 43 of Set 7 | karasburg
# Processing Record 44 of Set 7 | tanuku
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 7 | launceston
# Processing Record 48 of Set 7 | adolfo lopez mateos
# Processing Record 49 of Set 7 | naryan-mar
# Processing Record 50 of Set 7 | rundu
# Processing Record 1 of Set 8 | srednekolymsk
# Processing Record 2 of Set 8 | fort nelson
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | flin flon
# Processing Record 5 of Set 8 | serowe
# Processing Record 6 of Set 8 | rocha
# Processing Record 7 of Set 8 | bloemfontein
# Processing Record 8 of Set 8 | harrison
# Processing Record 9 of Set 8 | aksarka
# Processing Record 10 of Set 8 | becerril
# Processing Record 11 of Set 8 | vila velha
# Processing Record 12 of Set 8 | carnarvon
# Processing Record 13 of Set 8 | mersing
# Processing Record 14 of Set 8 | jizan
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | taoudenni
# Processing Record 18 of Set 8 | awjilah
# Processing Record 19 of Set 8 | tautira
# Processing Record 20 of Set 8 | taganak
# Processing Record 21 of Set 8 | nyimba
# Processing Record 22 of Set 8 | shuyskoye
# Processing Record 23 of Set 8 | san ignacio
# Processing Record 24 of Set 8 | koungou
# Processing Record 25 of Set 8 | nushki
# Processing Record 26 of Set 8 | tiznit
# Processing Record 27 of Set 8 | mareeba
# Processing Record 28 of Set 8 | harper
# Processing Record 29 of Set 8 | fortuna foothills
# Processing Record 30 of Set 8 | barreiras
# Processing Record 31 of Set 8 | poli
# Processing Record 32 of Set 8 | akhalgori
# Processing Record 33 of Set 8 | nizhniy baskunchak
# Processing Record 34 of Set 8 | tura
# Processing Record 35 of Set 8 | balaipungut
# Processing Record 36 of Set 8 | provideniya
# Processing Record 37 of Set 8 | nicoya
# Processing Record 38 of Set 8 | hastings
# Processing Record 39 of Set 8 | kita
# Processing Record 40 of Set 8 | puerto madryn
# Processing Record 41 of Set 8 | chippewa falls
# Processing Record 42 of Set 8 | humaita
# Processing Record 43 of Set 8 | upernavik
# Processing Record 44 of Set 8 | baykit
# Processing Record 45 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 8 | tumsar
# Processing Record 47 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 8 | sibu
# Processing Record 49 of Set 8 | porto velho
# Processing Record 50 of Set 8 | manica
# Processing Record 1 of Set 9 | margate
# Processing Record 2 of Set 9 | markova
# Processing Record 3 of Set 9 | lavumisa
# Processing Record 4 of Set 9 | cairns
# Processing Record 5 of Set 9 | grindavik
# Processing Record 6 of Set 9 | portsoy
# Processing Record 7 of Set 9 | betul
# Processing Record 8 of Set 9 | pangody
# Processing Record 9 of Set 9 | adrasmon
# Processing Record 10 of Set 9 | marystown
# Processing Record 11 of Set 9 | pingzhuang
# Processing Record 12 of Set 9 | marbella
# Processing Record 13 of Set 9 | luba
# Processing Record 14 of Set 9 | hofn
# Processing Record 15 of Set 9 | the valley
# Processing Record 16 of Set 9 | agadez
# Processing Record 17 of Set 9 | conakry
# Processing Record 18 of Set 9 | coos bay
# Processing Record 19 of Set 9 | morrope
# Processing Record 20 of Set 9 | upata
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | thanatpin
# Processing Record 23 of Set 9 | wajima
# Processing Record 24 of Set 9 | colares
# Processing Record 25 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 9 | lake city
# Processing Record 27 of Set 9 | palmer
# Processing Record 28 of Set 9 | conchas
# Processing Record 29 of Set 9 | niltepec
# Processing Record 30 of Set 9 | vanimo
# Processing Record 31 of Set 9 | parys
# Processing Record 32 of Set 9 | sundsvall
# Processing Record 33 of Set 9 | puerto lempira
# Processing Record 34 of Set 9 | beisfjord
# Processing Record 35 of Set 9 | caravelas
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | colac
# Processing Record 38 of Set 9 | dong hoi
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | boa vista
# Processing Record 41 of Set 9 | cabedelo
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | gouyave
# Processing Record 45 of Set 9 | acapulco
# Processing Record 46 of Set 9 | galveston
# Processing Record 47 of Set 9 | sao joao da barra
# Processing Record 48 of Set 9 | mitsamiouli
# Processing Record 49 of Set 9 | vestmanna
# Processing Record 50 of Set 9 | batemans bay
# Processing Record 1 of Set 10 | saurimo
# Processing Record 2 of Set 10 | pangkalanbuun
# Processing Record 3 of Set 10 | juneau
# Processing Record 4 of Set 10 | puerto colombia
# Processing Record 5 of Set 10 | zhumadian
# Processing Record 6 of Set 10 | lagos de moreno
# Processing Record 7 of Set 10 | fjerritslev
# Processing Record 8 of Set 10 | toulepleu
# City not found. Skipping...
# Processing Record 9 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 10 | kovernino
# Processing Record 11 of Set 10 | maceio
# Processing Record 12 of Set 10 | businga
# Processing Record 13 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 10 | bilma
# Processing Record 15 of Set 10 | middelburg
# Processing Record 16 of Set 10 | paamiut
# Processing Record 17 of Set 10 | maragogi
# Processing Record 18 of Set 10 | ponta delgada
# Processing Record 19 of Set 10 | chlumec nad cidlinou
# Processing Record 20 of Set 10 | pocatello
# Processing Record 21 of Set 10 | dongdu
# Processing Record 22 of Set 10 | tecoanapa
# Processing Record 23 of Set 10 | saint-leu
# Processing Record 24 of Set 10 | sakaraha
# Processing Record 25 of Set 10 | zyryanovsk
# Processing Record 26 of Set 10 | kahului
# Processing Record 27 of Set 10 | altay
# Processing Record 28 of Set 10 | cotusca
# Processing Record 29 of Set 10 | soyo
# Processing Record 30 of Set 10 | biskamzha
# Processing Record 31 of Set 10 | kaputa
# Processing Record 32 of Set 10 | pathein
# Processing Record 33 of Set 10 | cockburn town
# Processing Record 34 of Set 10 | marzuq
# Processing Record 35 of Set 10 | luorong
# Processing Record 36 of Set 10 | yelizovo
# Processing Record 37 of Set 10 | iwanai
# Processing Record 38 of Set 10 | uk
# City not found. Skipping...
# Processing Record 39 of Set 10 | morant bay
# Processing Record 40 of Set 10 | gizo
# Processing Record 41 of Set 10 | koindu
# Processing Record 42 of Set 10 | bardiyah
# Processing Record 43 of Set 10 | togur
# Processing Record 44 of Set 10 | kruisfontein
# Processing Record 45 of Set 10 | de-kastri
# Processing Record 46 of Set 10 | marawi
# Processing Record 47 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 10 | arroyo
# Processing Record 49 of Set 10 | nola
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | sars
# Processing Record 2 of Set 11 | nantucket
# Processing Record 3 of Set 11 | tual
# Processing Record 4 of Set 11 | kaniama
# Processing Record 5 of Set 11 | lauria
# Processing Record 6 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | touros
# Processing Record 9 of Set 11 | garmsar
# Processing Record 10 of Set 11 | lavras
# Processing Record 11 of Set 11 | arman
# Processing Record 12 of Set 11 | alofi
# Processing Record 13 of Set 11 | lichinga
# Processing Record 14 of Set 11 | heerenveen
# Processing Record 15 of Set 11 | inhambane
# Processing Record 16 of Set 11 | koumac
# Processing Record 17 of Set 11 | aras
# Processing Record 18 of Set 11 | bosaso
# Processing Record 19 of Set 11 | bambanglipuro
# Processing Record 20 of Set 11 | tabou
# Processing Record 21 of Set 11 | belmonte
# Processing Record 22 of Set 11 | alamosa
# Processing Record 23 of Set 11 | bathsheba
# Processing Record 24 of Set 11 | cozumel
# Processing Record 25 of Set 11 | jasper
# Processing Record 26 of Set 11 | namatanai
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | laguna
# Processing Record 29 of Set 11 | arrecife
# Processing Record 30 of Set 11 | grand bank
# Processing Record 31 of Set 11 | bayir
# Processing Record 32 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 11 | salto
# Processing Record 34 of Set 11 | hovd
# Processing Record 35 of Set 11 | wamba
# Processing Record 36 of Set 11 | utrecht
# Processing Record 37 of Set 11 | gigmoto
# Processing Record 38 of Set 11 | kalulushi
# Processing Record 39 of Set 11 | manga
# Processing Record 40 of Set 11 | northam
# Processing Record 41 of Set 11 | koshurnikovo
# Processing Record 42 of Set 11 | benguela
# Processing Record 43 of Set 11 | atherton
# Processing Record 44 of Set 11 | kuryk
# Processing Record 45 of Set 11 | uige
# Processing Record 46 of Set 11 | zyryanka
# Processing Record 47 of Set 11 | vostok
# Processing Record 48 of Set 11 | tambura
# Processing Record 49 of Set 11 | shubarkuduk
# Processing Record 50 of Set 11 | isla mujeres
# Processing Record 1 of Set 12 | vestmannaeyjar
# Processing Record 2 of Set 12 | berlevag
# Processing Record 3 of Set 12 | ugoofaaru
# Processing Record 4 of Set 12 | port hardy
# Processing Record 5 of Set 12 | maumere
# Processing Record 6 of Set 12 | chapais
# Processing Record 7 of Set 12 | kant
# Processing Record 8 of Set 12 | iquitos
# Processing Record 9 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 12 | biltine
# Processing Record 11 of Set 12 | ankang
# Processing Record 12 of Set 12 | sao felix do xingu
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | aban
# Processing Record 15 of Set 12 | araguacu
# Processing Record 16 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 17 of Set 12 | luderitz
# Processing Record 18 of Set 12 | taraza
# Processing Record 19 of Set 12 | bom jardim
# Processing Record 20 of Set 12 | florida
# Processing Record 21 of Set 12 | santo tomas
# Processing Record 22 of Set 12 | sokolo
# Processing Record 23 of Set 12 | fukue
# Processing Record 24 of Set 12 | mahibadhoo
# Processing Record 25 of Set 12 | oranjestad
# Processing Record 26 of Set 12 | ewo
# Processing Record 27 of Set 12 | auki
# Processing Record 28 of Set 12 | ostrovnoy
# Processing Record 29 of Set 12 | bantou
# Processing Record 30 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 12 | mayor pablo lagerenza
# Processing Record 32 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 12 | cayenne
# Processing Record 34 of Set 12 | springbok
# Processing Record 35 of Set 12 | kheri
# Processing Record 36 of Set 12 | conceicao da barra
# Processing Record 37 of Set 12 | rodrigues alves
# Processing Record 38 of Set 12 | jibuti
# Processing Record 39 of Set 12 | moyale
# Processing Record 40 of Set 12 | ojinaga
# Processing Record 41 of Set 12 | gurgentepe
# Processing Record 42 of Set 12 | tuatapere
# Processing Record 43 of Set 12 | puerto madero
# Processing Record 44 of Set 12 | sembe
# Processing Record 45 of Set 12 | khuzhir
# Processing Record 46 of Set 12 | dalby
# Processing Record 47 of Set 12 | carutapera
# Processing Record 48 of Set 12 | uthai thani
# Processing Record 49 of Set 12 | resistencia
# Processing Record 50 of Set 12 | quartucciu
# Processing Record 1 of Set 13 | ziro
# Processing Record 2 of Set 13 | birjand
# Processing Record 3 of Set 13 | big bend
# Processing Record 4 of Set 13 | saint-francois
# Processing Record 5 of Set 13 | kirakira
# Processing Record 6 of Set 13 | srivardhan
# Processing Record 7 of Set 13 | georgiyevka
# Processing Record 8 of Set 13 | zhangye
# Processing Record 9 of Set 13 | menomonie
# Processing Record 10 of Set 13 | worthington
# Processing Record 11 of Set 13 | repelon
# Processing Record 12 of Set 13 | saint-georges
# Processing Record 13 of Set 13 | marsh harbour
# Processing Record 14 of Set 13 | tortoli
# Processing Record 15 of Set 13 | cancun
# Processing Record 16 of Set 13 | lagoa
# Processing Record 17 of Set 13 | kapuskasing
# Processing Record 18 of Set 13 | bengkulu
# Processing Record 19 of Set 13 | lillooet
# Processing Record 20 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 13 | trelleborg
# Processing Record 22 of Set 13 | xiangdong
# City not found. Skipping...
# Processing Record 23 of Set 13 | joshimath
# Processing Record 24 of Set 13 | rakhya
# City not found. Skipping...
# Processing Record 25 of Set 13 | madingou
# Processing Record 26 of Set 13 | timmins
# Processing Record 27 of Set 13 | poshekhonye
# Processing Record 28 of Set 13 | altamont
# Processing Record 29 of Set 13 | caluquembe
# Processing Record 30 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 31 of Set 13 | lolodorf
# Processing Record 32 of Set 13 | tyup
# Processing Record 33 of Set 13 | kuruman
# Processing Record 34 of Set 13 | watertown
# Processing Record 35 of Set 13 | teya
# Processing Record 36 of Set 13 | salaga
# Processing Record 37 of Set 13 | tauberbischofsheim
# Processing Record 38 of Set 13 | energetik
# Processing Record 39 of Set 13 | ardakan
# Processing Record 40 of Set 13 | ahuimanu
# Processing Record 41 of Set 13 | usinsk
# Processing Record 42 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 13 | bodden town
# Processing Record 44 of Set 13 | staryy nadym
# Processing Record 45 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 13 | manono
# Processing Record 47 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 13 | kamina
# Processing Record 49 of Set 13 | monastyrshchina
# Processing Record 50 of Set 13 | chernyshevskiy
# Processing Record 1 of Set 14 | umuarama
# Processing Record 2 of Set 14 | krasnoselkup
# Processing Record 3 of Set 14 | oistins
# Processing Record 4 of Set 14 | warrnambool
# Processing Record 5 of Set 14 | cooma
# Processing Record 6 of Set 14 | mirnyy
# Processing Record 7 of Set 14 | goleniow
# Processing Record 8 of Set 14 | suamico
# Processing Record 9 of Set 14 | anadyr
# Processing Record 10 of Set 14 | smila
# Processing Record 11 of Set 14 | ampanihy
# Processing Record 12 of Set 14 | damietta
# Processing Record 13 of Set 14 | muros
# Processing Record 14 of Set 14 | kaeo
# Processing Record 15 of Set 14 | george
# Processing Record 16 of Set 14 | camana
# Processing Record 17 of Set 14 | port huron
# Processing Record 18 of Set 14 | izhma
# Processing Record 19 of Set 14 | henties bay
# Processing Record 20 of Set 14 | matagami
# Processing Record 21 of Set 14 | angoram
# Processing Record 22 of Set 14 | terenos
# Processing Record 23 of Set 14 | te anau
# Processing Record 24 of Set 14 | bayji
# Processing Record 25 of Set 14 | brigantine
# Processing Record 26 of Set 14 | tamiahua
# Processing Record 27 of Set 14 | kushmurun
# Processing Record 28 of Set 14 | mayo
# Processing Record 29 of Set 14 | ransang
# Processing Record 30 of Set 14 | ubinskoye
# Processing Record 31 of Set 14 | hoopstad
# Processing Record 32 of Set 14 | oktyabrskoye
# Processing Record 33 of Set 14 | matviyivka
# Processing Record 34 of Set 14 | hokitika
# Processing Record 35 of Set 14 | coronel fabriciano
# Processing Record 36 of Set 14 | havoysund
# Processing Record 37 of Set 14 | indramayu
# Processing Record 38 of Set 14 | liuhe
# Processing Record 39 of Set 14 | songkhla
# Processing Record 40 of Set 14 | malangali
# Processing Record 41 of Set 14 | yulara
# Processing Record 42 of Set 14 | kalaleh
# Processing Record 43 of Set 14 | adelaide
# Processing Record 44 of Set 14 | bucerias
# Processing Record 45 of Set 14 | juanjui
# Processing Record 46 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 14 | daokou
# Processing Record 48 of Set 14 | kovylkino
# Processing Record 49 of Set 14 | yumen
# Processing Record 50 of Set 14 | moose factory
# Processing Record 1 of Set 15 | erenhot
# Processing Record 2 of Set 15 | havre-saint-pierre
# Processing Record 3 of Set 15 | eirunepe
# Processing Record 4 of Set 15 | polunochnoye
# Processing Record 5 of Set 15 | cavalcante
# Processing Record 6 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 7 of Set 15 | popondetta
# Processing Record 8 of Set 15 | novosergiyevka
# Processing Record 9 of Set 15 | keti bandar
# Processing Record 10 of Set 15 | atlantic city
# Processing Record 11 of Set 15 | fethiye
# Processing Record 12 of Set 15 | dzaoudzi
# Processing Record 13 of Set 15 | shitanjing
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | jalu
# Processing Record 16 of Set 15 | umm lajj
# Processing Record 17 of Set 15 | myrtle beach
# Processing Record 18 of Set 15 | podporozhye
# Processing Record 19 of Set 15 | santa isabel do rio negro
# Processing Record 20 of Set 15 | araras
# Processing Record 21 of Set 15 | abancay
# Processing Record 22 of Set 15 | frontignan
# Processing Record 23 of Set 15 | mago
# Processing Record 24 of Set 15 | kailua
# Processing Record 25 of Set 15 | kalomo
# City not found. Skipping...
# Processing Record 26 of Set 15 | caborca
# Processing Record 27 of Set 15 | ouango
# Processing Record 28 of Set 15 | tenenkou
# Processing Record 29 of Set 15 | camacha
# Processing Record 30 of Set 15 | ridgecrest
# Processing Record 31 of Set 15 | verkhoyansk
# Processing Record 32 of Set 15 | takoradi
# Processing Record 33 of Set 15 | kieta
# Processing Record 34 of Set 15 | katima mulilo
# Processing Record 35 of Set 15 | makasar
# Processing Record 36 of Set 15 | lavrentiya
# Processing Record 37 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 15 | bouafle
# Processing Record 39 of Set 15 | svetlopolyansk
# Processing Record 40 of Set 15 | trincomalee
# Processing Record 41 of Set 15 | waingapu
# Processing Record 42 of Set 15 | tessalit
# Processing Record 43 of Set 15 | conceicao do araguaia
# Processing Record 44 of Set 15 | vao
# Processing Record 45 of Set 15 | ikongo
# Processing Record 46 of Set 15 | barabai
# Processing Record 47 of Set 15 | honningsvag
# Processing Record 48 of Set 15 | sioux lookout
# Processing Record 49 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 50 of Set 15 | sherbakul
# Processing Record 1 of Set 16 | rajsamand
# Processing Record 2 of Set 16 | troitskoye
# Processing Record 3 of Set 16 | barberton
# Processing Record 4 of Set 16 | salihorsk
# Processing Record 5 of Set 16 | martaban
# Processing Record 6 of Set 16 | elmira
# Processing Record 7 of Set 16 | shahreza
# Processing Record 8 of Set 16 | chumikan
# Processing Record 9 of Set 16 | nha trang
# Processing Record 10 of Set 16 | ambilobe
# Processing Record 11 of Set 16 | viedma
# Processing Record 12 of Set 16 | fort-shevchenko
# Processing Record 13 of Set 16 | dzhebariki-khaya
# Processing Record 14 of Set 16 | payson
# Processing Record 15 of Set 16 | camopi
# Processing Record 16 of Set 16 | yarega
# Processing Record 17 of Set 16 | lodja
# Processing Record 18 of Set 16 | palauig
# Processing Record 19 of Set 16 | torring
# Processing Record 20 of Set 16 | manzhouli
# Processing Record 21 of Set 16 | yarmouth
# Processing Record 22 of Set 16 | brooks
# Processing Record 23 of Set 16 | kenai
# Processing Record 24 of Set 16 | hirara
# Processing Record 25 of Set 16 | aquiraz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries using the len() function.
len(city_data)
# Out:
# 720

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Atuona  -9.8000 -139.0333     76.96        66          40
# 1                   Lebu -37.6167  -73.6500     53.38        85         100
# 2            Antanifotsy -19.6500   47.3167     68.67        33           3
# 3             Butaritari   3.0707  172.7902     82.36        74          78
# 4                 Torbay  47.6666  -52.7314     74.75        74          75
# 5                Rikitea -23.1203 -134.9692     75.33        78          25
# 6             Hambantota   6.1241   81.1185     91.74        66          20
# 7  Los Llanos De Aridane  28.6585  -17.9182     74.95        78           0
# 8           Jan Kempdorp -27.9225   24.8305     60.57        18           0
# 9              Saskylakh  71.9167  114.0833     77.31        43         100
#
#    Wind Speed Country Current Description
# 0       15.03      PF    scattered clouds
# 1       18.25      CL     overcast clouds
# 2        4.34      MG           clear sky
# 3       16.24      KI       broken clouds
# 4       13.80      CA       broken clouds
# 5       17.69      PF    scattered clouds
# 6       12.66      LK          few clouds
# 7       12.66      ES           clear sky
# 8        3.85      ZA           clear sky
# 9        7.23      RU     overcast clouds

# %%
# Reorder the columns in the city_data_df.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Atuona      PF  -9.8000 -139.0333     76.96        66
# 1                   Lebu      CL -37.6167  -73.6500     53.38        85
# 2            Antanifotsy      MG -19.6500   47.3167     68.67        33
# 3             Butaritari      KI   3.0707  172.7902     82.36        74
# 4                 Torbay      CA  47.6666  -52.7314     74.75        74
# 5                Rikitea      PF -23.1203 -134.9692     75.33        78
# 6             Hambantota      LK   6.1241   81.1185     91.74        66
# 7  Los Llanos De Aridane      ES  28.6585  -17.9182     74.95        78
# 8           Jan Kempdorp      ZA -27.9225   24.8305     60.57        18
# 9              Saskylakh      RU  71.9167  114.0833     77.31        43
#
#    Cloudiness  Wind Speed Current Description
# 0          40       15.03    scattered clouds
# 1         100       18.25     overcast clouds
# 2           3        4.34           clear sky
# 3          78       16.24       broken clouds
# 4          75       13.80       broken clouds
# 5          25       17.69    scattered clouds
# 6          20       12.66          few clouds
# 7           0       12.66           clear sky
# 8           0        3.85           clear sky
# 9         100        7.23     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
